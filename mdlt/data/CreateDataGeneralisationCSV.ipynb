# %%
import pandas as pd
import numpy as np
Dataset='VLCS'
filename=Dataset+'/'+Dataset+'.csv'
data=pd.read_csv(filename,header=[0])
data.reset_index()
data.drop('split',axis=1)
# Out:
#        index         env  label  \
# 0          0  Caltech101      0
# 1          1  Caltech101      0
# 2          2  Caltech101      0
# 3          3  Caltech101      0
# 4          4  Caltech101      0
# ...      ...         ...    ...
# 10724  10724     VOC2007      4
# 10725  10725     VOC2007      4
# 10726  10726     VOC2007      4
# 10727  10727     VOC2007      4
# 10728  10728     VOC2007      4
#
#                                                     path  split
# 0      Caltech101/bird/24cfa9d5209f45e687ab0c6a4432c2...   test
# 1      Caltech101/bird/e0fd86f12ca744d9a698fc9282af21...  train
# 2      Caltech101/bird/d8003f02fc494840a28936b0f260c9...  train
# 3      Caltech101/bird/b75057e997a748338e1c8d52597dba...  train
# 4      Caltech101/bird/fa832d8a43f7436dbf6fe01c0f693a...  train
# ...                                                  ...    ...
# 10724  VOC2007/person/2177b325b189430b9cd8c4ef472362a...  train
# ...

# %%
def data4DG(data,Dataset):
######################################
# For every unique class in env, we create a different csv file 
#####################################
    
    Files=data['env'].unique()
    for i in Files:
        data1=data[:]
        data1['split']=np.where(data1.env==i,'val','train')
        start=data1[data1['env']==i].iloc[0].name
        end=data1[data1['env']==i].iloc[-1].name+1
        data1['split'][start:end]=np.where(data1['split'][start:end].index % 2 ==0,'val','test')        
        
        filename=Dataset+'/'+Dataset+'_'+i+'.csv'
        data1.to_csv(filename)

# %%
data4DG(data,Dataset)
# Out:
# /tmp/ipykernel_165692/3129931097.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['split'][start:end]=np.where(data1['split'][start:end].index % 2 ==0,'val','test')
# /tmp/ipykernel_165692/3129931097.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['split'][start:end]=np.where(data1['split'][start:end].index % 2 ==0,'val','test')
# /tmp/ipykernel_165692/3129931097.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...
